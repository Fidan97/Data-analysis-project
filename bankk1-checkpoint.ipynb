# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bank_customers.csv')
df
# Out:
#                               customer_id                name  age  gender  \
# 0    7e5504da-a2ea-4a4c-8db4-30e9ad17c251     Yolanda Andrade   33    Male
# 1    bd41ef21-fb05-4430-8f29-8a32f0572af2  Christopher Castro   62  Others
# 2    8616720c-1254-40e7-aedb-f91f9a336c43         David Myers   49  Female
# 3    b4eda5fd-b2f6-4a8e-8470-7b11168011d8         Roy Hoffman   31  Others
# 4    8e1d9651-9515-44c0-9e0c-ddc68a4df0b1      Stanley Fields   18    Male
# ..                                    ...                 ...  ...     ...
# 505  c19b93b8-5064-4d03-9340-0500ce4e07d4          Megan King   38  Female
# 506  6b8b71fc-1cf2-4f85-b805-d36c6e6a0a22          John Scott   48  Others
# 507  d19cd1fb-e56f-48e8-8c93-90181ac8e7a1      Sherri Jenkins   64  Female
# 508  bb1ba3ba-6a0c-4752-b3ae-3fac88058558    Cynthia Richards   59  Female
# 509  89b70be6-0c8c-4f13-95ef-b1e7e2fbf1bc           John Vega   37  Others
#
#     marital_status    education   job_title   income  loan_amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            497 non-null    object
#  1   name                   510 non-null    object
#  2   age                    510 non-null    int64
#  3   gender                 510 non-null    object
#  4   marital_status         510 non-null    object
#  5   education              510 non-null    object
#  6   job_title              510 non-null    object
#  7   income                 485 non-null    float64
#  8   loan_amount            492 non-null    float64
#  9   loan_approved          510 non-null    object
#  10  credit_score           494 non-null    float64
#  11  account_balance        510 non-null    float64
#  12  branch                 510 non-null    object
#  13  registration_date      510 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# customer_id               13
# name                       0
# age                        0
# gender                     0
# marital_status             0
# education                  0
# job_title                  0
# income                    25
# loan_amount               18
# loan_approved              0
# credit_score              16
# account_balance            0
# branch                     0
# registration_date          0
# last_transaction_date      0
# has_credit_card            0
# defaulted_before           0
# email                      0
# phone_number               0
# notes                    161
# dtype: int64

# %%
df['income'].fillna(df['income'].mean(),inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8468\440867934.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['income'].fillna(df['income'].mean(),inplace=True)

# %%
df['loan_amount'].fillna(df['loan_amount'].mean(),inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8468\3901461652.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['loan_amount'].fillna(df['loan_amount'].mean(),inplace=True)

# %%
df['credit_score'].fillna(df['credit_score'].mean(),inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8468\2548722.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['credit_score'].fillna(df['credit_score'].mean(),inplace=True)

# %%
df['customer_id'].fillna('unknown',inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8468\3453458217.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customer_id'].fillna('unknown',inplace=True)

# %%
df.drop(columns=['notes'], inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id              0
# name                     0
# age                      0
# gender                   0
# marital_status           0
# education                0
# job_title                0
# income                   0
# loan_amount              0
# loan_approved            0
# credit_score             0
# account_balance          0
# branch                   0
# registration_date        0
# last_transaction_date    0
# has_credit_card          0
# defaulted_before         0
# email                    0
# phone_number             0
# dtype: int64

# %%
df.describe()
# Out:
#               age       income  loan_amount  credit_score  account_balance
# count  510.000000   510.000000    510.00000    510.000000       510.000000
# mean    43.566667  1199.953814   4917.98311    564.392713      2076.875588
# std     15.067447   478.794769   2720.61096    153.814190      1559.993103
# min     18.000000  -289.380000     97.78000    301.000000     -3122.940000
# 25%     31.000000   912.842500   2941.14000    442.250000      1076.455000
# 50%     42.000000  1199.953814   4917.98311    564.392713      1977.475000
# 75%     57.000000  1479.777500   6841.07750    693.500000      3019.217500
# max     70.000000  2611.250000  14445.63000    849.000000      6632.610000

# %%
df.dtypes
# Out:
# customer_id               object
# name                      object
# age                        int64
# gender                    object
# marital_status            object
# education                 object
# job_title                 object
# income                   float64
# loan_amount              float64
# loan_approved             object
# credit_score             float64
# account_balance          float64
# branch                    object
# registration_date         object
# last_transaction_date     object
# has_credit_card           object
# defaulted_before          object
# email                     object
# phone_number              object
# dtype: object

# %%
df.columns
# Out:
# Index(['customer_id', 'name', 'age', 'gender', 'marital_status', 'education',
#        'job_title', 'income', 'loan_amount', 'loan_approved', 'credit_score',
#        'account_balance', 'branch', 'registration_date',
#        'last_transaction_date', 'has_credit_card', 'defaulted_before', 'email',
#        'phone_number'],
#       dtype='object')

# %%
df['branch'].unique()
# Out:
# array(['Lənkəran', 'Bakı', 'Gəncə', 'Sumqayıt', 'Şəki'], dtype=object)

# %%
df['marital_status'].unique()
# Out:
# array(['Divorced', 'Married', 'Single'], dtype=object)

# %%
df.shape
# Out:
# (510, 19)

# %%
df['income'].agg(['min','max'])
# Out:
# min    -289.38
# max    2611.25
# Name: income, dtype: float64

# %%
sns.countplot(df['branch'])
plt.show()

# %%
sns.countplot(df['education'])
plt.show()

# %%
sns.countplot(df['job_title'])
plt.show()

# %%
sns.histplot(df['education'])
plt.title('education rate')
plt.xlabel('names')
plt.ylabel('amount')
plt.show()

# %%
df.groupby('age')['income'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df.groupby('age')['account_balance'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df.head()
# Out:
#                             customer_id                name  age  gender  \
# 0  7e5504da-a2ea-4a4c-8db4-30e9ad17c251     Yolanda Andrade   33    Male
# 1  bd41ef21-fb05-4430-8f29-8a32f0572af2  Christopher Castro   62  Others
# 2  8616720c-1254-40e7-aedb-f91f9a336c43         David Myers   49  Female
# 3  b4eda5fd-b2f6-4a8e-8470-7b11168011d8         Roy Hoffman   31  Others
# 4  8e1d9651-9515-44c0-9e0c-ddc68a4df0b1      Stanley Fields   18    Male
#
#   marital_status    education  job_title       income  loan_amount  \
# 0       Divorced    Bachelors   Mühəndis   689.280000      3739.94
# 1       Divorced  High School  Programçı  1490.310000      6881.41
# 2        Married    Bachelors     Satıcı  1199.953814      5501.52
# 3       Divorced    Bachelors     Tələbə  1689.200000     14445.63
# 4       Divorced          PhD  Programçı  1008.560000      6189.01
#
#   loan_approved  credit_score  account_balance    branch registration_date  \
# ...

# %%
df[df['email'].str.contains('hotmail', na=False)].head()
# Out:
#                              customer_id                name  age  gender  \
# 1   bd41ef21-fb05-4430-8f29-8a32f0572af2  Christopher Castro   62  Others
# 6   41425480-c3d1-4277-9a7d-8e1d369f1275      Tammy Davis MD   34  Female
# 10  d79666cd-dd3a-40dd-afa1-d77ae7f9a1b8      Melanie Taylor   48  Female
# 27  9be26a74-ba57-444c-8be7-8629c7b43625       Lisa Anderson   39  Others
# 29  aaaf41c4-1fc7-4a1e-939f-92c07338f3a4        Leslie Carey   60  Others
#
#    marital_status    education   job_title   income  loan_amount  \
# 1        Divorced  High School   Programçı  1490.31      6881.41
# 6         Married          PhD    Mühəndis   473.55      6319.76
# 10       Divorced          PhD   Programçı  2186.90      4630.08
# 27        Married      Masters  Marketoloq  1711.04      2489.64
# 29        Married    Bachelors      Tələbə  1462.16      7737.70
#
#    loan_approved  credit_score  account_balance    branch registration_date  \
# ...

# %%
df[df['email'].str.contains('yahoo', na=False)].head()
# Out:
#                              customer_id              name  age  gender  \
# 0   7e5504da-a2ea-4a4c-8db4-30e9ad17c251   Yolanda Andrade   33    Male
# 8   8e65684f-f83b-4a2e-a085-f513a67e4e02       Ryan Willis   40    Male
# 9   f94e8f37-f7e6-4933-9588-ceaadaaa3fe5  Kimberly Bradley   50  Female
# 11  b65b667e-7fbe-4de0-bdc4-ececeb932b62     Clayton Clark   59  Female
# 12  f4a871b9-19f8-4e5a-8ee9-7022ffc464c5     Valerie Smith   36    Male
#
#    marital_status  education job_title   income  loan_amount loan_approved  \
# 0        Divorced  Bachelors  Mühəndis   689.28      3739.94           Yes
# 8         Married        PhD   Menecer  1345.07      2693.38            No
# 9         Married    Masters  Mühəndis  1953.99      3595.54            No
# 11       Divorced  Bachelors   Mühasib   725.55       927.37            No
# 12       Divorced    Masters   Menecer  2387.23      4570.67           Yes
#
#     credit_score  account_balance    branch registration_date  \
# ...

# %%
df[(df['education'].str.contains('PhD', na=False)) & (df['gender'] == 'Female')  & (df['age'] >= 40)].head()
# Out:
#                               customer_id                name  age  gender  \
# 10   d79666cd-dd3a-40dd-afa1-d77ae7f9a1b8      Melanie Taylor   48  Female
# 103  e4a2ef26-fd31-4a59-a23f-1e2745e7302e        Kevin Thomas   42  Female
# 125  1d4f23bd-cd11-4246-8095-82b17ae51caa    Robert Schneider   46  Female
# 138  71a5dd3a-db76-46de-9a84-33b2e0331c11     Makayla Simmons   56  Female
# 197  2d2509c4-d76b-4695-b691-c8515e884175  Catherine Williams   50  Female
#
#     marital_status education  job_title   income  loan_amount loan_approved  \
# 10        Divorced       PhD  Programçı  2186.90      4630.08            No
# 103       Divorced       PhD     Tələbə  1239.12      1169.10            No
# 125       Divorced       PhD    Mühasib   310.92      9786.03           Yes
# 138         Single       PhD     Tələbə  1554.40      4381.85           Yes
# 197         Single       PhD    Mühasib  1019.73      8250.33           Yes
#
# ...

# %%
df[['loan_amount','income','credit_score','account_balance']].corr()
# Out:
#                  loan_amount    income  credit_score  account_balance
# loan_amount         1.000000  0.060039      0.040339        -0.067028
# income              0.060039  1.000000     -0.008814        -0.019375
# credit_score        0.040339 -0.008814      1.000000         0.019262
# account_balance    -0.067028 -0.019375      0.019262         1.000000

# %%
df.groupby('gender')['income'].mean()
# Out:
# gender
# Female    1145.677093
# Male      1243.207695
# Others    1208.041844
# Name: income, dtype: float64

# %%
df['education'].mode()
# Out:
# 0    High School
# 1        Masters
# Name: education, dtype: object

# %%
df['gender'].mode()
# Out:
# 0    Others
# Name: gender, dtype: object

# %%
sns.boxplot(df['income'])
# Out:
# <Axes: ylabel='income'>
